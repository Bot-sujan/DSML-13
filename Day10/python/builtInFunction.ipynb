# %% [markdown]
# map(), filter() and reduce()

# %%
def get_cube(num):
    return num **3
ls = [1, 4, 8, 2, 6, 9]

map_obj = map(get_cube, ls)
map_obj

# %% [markdown]
# reduce()
# The reduce() function in Python is used to apply a given function to the item of an iterable.

# %%
from functools import reduce

# %%
def add(x,y):
    return x + y
