# %% [markdown]
# Function in Python can also have variable-length arguments lists. These are called *args and **kwargs, and they allow the function to accept any number of arguments and keyword arguments, respectively. Here's an example.

# %%
     ## buit in function
     ## user-defined function
     ## lambda function
