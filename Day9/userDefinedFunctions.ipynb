# %% [markdown]
# Python Function
# A function is a block of code that performs a specific task.
#
# def<function_name>(parameters):
#    so something
#    .
#    .
#    return<result>

# %%
def calculate_sum(num1, num2):
    result = num1 + num2
    return result

nein = calculate_sum(5,10)
res = calculate_sum([3,8], [4, 9]),
print(nein)
print(res)
# Out:
# 15
# ([3, 8, 4, 9],)

# %%
res = calculate_sum(1.4, 1.5)
print(res)
# Out:
# 2.9

# %%
def greet(name: str, greeting = "Morning"):
    print(f"Good {greeting}, {name}")

greet("Rohit")
# Out:
# Good Morning, Rohit
