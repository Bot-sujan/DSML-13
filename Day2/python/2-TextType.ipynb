# %%
name = "Sujan Pandey"
type (name)
# Out:
# str

# %%
x = "sujan pandey"
x.upper()
y = x
y.lower()
# Out:
# 'sujan pandey'

# %%
x = ("Hello, World!")
x.replace("H", "S")
# Out:
# 'Sello, World!'

# %%
x.split(",")
# Out:
# ['Hello', ' World!']

# %%
email = "sujanpandey747@gmail.com"
email.lower().endswith("skill.com")
# Out:
# False

# %% [markdown]
# ## String indexing
# ## you can access individual characters in a string using indexing in python, indexingn starts at 0.

# %%
address = "Raniban,Dhungedhara,73"
address[10]
address[6]
# Out:
# 'n'

# %%
address [3: 10: 2]
# Out:
# 'ia,h'

# %%
text = "pandey"
text[::-1]
# Out:
# 'najus'

# %%
"sujan" > "Pandey"
# Out:
# True

# %%
info = f"Your name is {name} and your email is {email}"
info
# Out:
# 'Your name is Sujan Pandey and your email is sujanpandey747@gmail.com'

# %%
name = "sandesh"
msg_template = f"hello {name}, welcome to the world of python"
msg_template
# Out:
# 'hello sandesh, welcome to the world of python'

# %%
long_string = """This is a long 
string that spans 
multiple lines."""
print(long_string)
# Out:
# This is a long
# string that spans
# multiple lines.
