# %%
num2 = float(32.322)
num2

a = 32
b = 43
c = a + b
c
# Out:
# 75

# %%
c = 5 % 3
c

s = 6 ** 2.5
s

5 != 4
# Out:
# True

# %%
import math

math.sqrt(25)
math.dist((2,5,6,9,3,7), (3,5,7,9,2,1))
# Out:
# 6.244997998398398

# %%
round(math.pi, 4)
# Out:
# 3.1416
