# %%
class Person:
    def __init__(self, name):
        self.full_name = name

    @property
    def name(self):
        print("Getting name")
        return self.full_name


obj = Person("Ram_pd.Luitel")
obj.name
# Out:
#   Cell In[1], line 4
#     @property
#     ^
# IndentationError: expected an indented block after function definition on line 2
